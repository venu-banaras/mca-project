# %% [markdown]
# <a href="https://colab.research.google.com/github/venu-banaras/mca-project/blob/master/test_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/venu-banaras/mca-project.git
# !git remote set-url origin https://venu-banaras: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@github.com/venu-banaras/mca-project.git
# Out:
# Cloning into 'mca-project'...
# remote: Enumerating objects: 12927, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 12927 (delta 9), reused 95 (delta 4), pack-reused 12815
# Receiving objects: 100% (12927/12927), 188.43 MiB | 17.90 MiB/s, done.
# Resolving deltas: 100% (7466/7466), done.
# Checking out files: 100% (1872/1872), done.

# %%
# %cd mca-project
# Out:
# /content/mca-project

# %%
# %pip install -qr requirements.txt
# Out:
#      |████████████████████████████████| 1.6 MB 15.4 MB/s

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v1.0-4-g7154ad0 Python-3.7.15 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.0/78.2 GB disk)

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 600 --conf 0.1 --source 'https://www.youtube.com/watch?v=Z12JRIVVyhw&t=232s'
# Out:
# Streaming output truncated to the last 5000 lines.
# 0: 352x608 2 Buildingss, 9.6ms
# 0: 352x608 2 Buildingss, 9.8ms
# 0: 352x608 2 Buildingss, 9.9ms
# 0: 352x608 2 Buildingss, 10.1ms
# 0: 352x608 2 Buildingss, 10.5ms
# 0: 352x608 2 Buildingss, 10.5ms
# 0: 352x608 2 Buildingss, 10.4ms
# 0: 352x608 2 Buildingss, 10.3ms
# 0: 352x608 2 Buildingss, 10.6ms
# 0: 352x608 2 Buildingss, 10.0ms
# 0: 352x608 2 Buildingss, 9.7ms
# 0: 352x608 2 Buildingss, 9.6ms
# 0: 352x608 2 Buildingss, 9.6ms
# 0: 352x608 2 Buildingss, 9.5ms
# 0: 352x608 2 Buildingss, 9.5ms
# 0: 352x608 2 Buildingss, 9.5ms
# 0: 352x608 2 Buildingss, 9.5ms
# 0: 352x608 2 Buildingss, 9.5ms
# 0: 352x608 2 Buildingss, 9.6ms
# 0: 352x608 2 Buildingss, 9.4ms
# 0: 352x608 2 Buildingss, 12.2ms
# 0: 352x608 2 Buildingss, 9.6ms
# 0: 352x608 4 Buildingss, 14.7ms
# 0: 352x608 3 Buildingss, 9.8ms
# 0: 352x608 3 Buildingss, 9.8ms
# 0: 352x608 3 Buildingss, 10.4ms
# 0: 352x608 3 Buildingss, 10.2ms
# 0: 352x608 3 Buildingss, 9.8ms
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 600 --conf 0.1 --source 'https://www.youtube.com/watch?v=bJoQ1Wwt-Bg&t=36s'

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,10))
img = plt.imread('runs/detect/exp2/mediumresidential_129_jpg.rf.77c78b01e2740242d890a19fe113927b.jpg')
plt.imshow(img)

# %%
plt.figure(figsize=(12,10))
img = plt.imread('runs/detect/exp/mediumresidential_90_jpg.rf.db62b88e7bbcff1f5aebed43c2f2158f.jpg')
plt.imshow(img)

# %%
plt.figure(figsize=(12,10))
img = plt.imread('runs/detect/exp2/mediumresidential_284_jpg.rf.9decf57f6cd418a425523f48f590b6d1.jpg')
plt.imshow(img)

# %%
# !git remote set-url origin https://github.com/venu-banaras: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/videodownloading.git

# %%
# !git push -u origin master
# Out:
# fatal: unable to access 'https://github.com/venu-banaras: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/videodownloading.git/': The requested URL returned error: 400

# %%
# !git add -f .
# !git commit -m "video"
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git config --global user.email "venu.banaras@gmail.com"
# !git config --global user.name "venu-banaras"

# %%
# !git commit -m "video"
# Out:
# On branch master
# Your branch is ahead of 'origin/master' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !git push -u origin master
# Out:
# fatal: unable to access 'https://github.com/venu-banaras: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/videodownloading.git/': The requested URL returned error: 400

# %%
# !touch "/content/mca-project/runs/detect/exp3/watch_v_Z12JRIVVyhw_t_232s.mp4"

# %%
# %cd drive/My-Drive/
# Out:
# [Errno 2] No such file or directory: 'drive/My-Drive/'
# /content/mca-project

# %%
# !mv '/content/mca-project/runs/detect/exp3/watch_v_Z12JRIVVyhw_t_232s.mp4'

# %%
#path that contains folder you want to copy
# %cd content/mca-project/runs/detect/exp3/watch_v_Z12JRIVVyhw_t_232s.mp4
# %cp -av YOUR_FOLDER NEW_FOLDER_COPY
# Out:
# [Errno 2] No such file or directory: 'content/mca-project/runs/detect/exp3/watch_v_Z12JRIVVyhw_t_232s.mp4'
# /content/mca-project
